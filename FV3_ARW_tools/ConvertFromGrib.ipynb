# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import netCDF4 as ncdf
import matplotlib as mlab
import matplotlib.pyplot as plt
import xarray as xr
import glob as glob
import os as os
import sys as sys
from file_tools import *

# These are 45 vertical levels that the FV3 puts out - use them here to map ARW to that grid for comparison

plevels = np.asarray([100000.,  97500.,  95000.,  92500.,  90000.,  87500.,  85000.,  82500.,
                       80000.,  77500.,  75000.,  72500.,  70000.,  67500.,  65000.,  62500.,
                       60000.,  57500.,  55000.,  52500.,  50000.,  47500.,  45000.,  42500.,
                       40000.,  37500.,  35000.,  32500.,  30000.,  27500.,  25000.,  22500.,
                       20000.,  17500.,  15000.,  12500.,  10000.,   7000.,   5000.,   3000.,
                        2000.,   1000.,    700.,    500.,    200.])

nz_new = plevels.shape[0]

_w_threshold = 5.0
_Rgas       = 287.04
_gravity    = 9.806

# default setting for domain cutting

sw_corner = None
ne_corner = None

plot_one  = True
plot_time = 4     # usually there are 6-7 files, so plot the fourth file

# %%
#-------------------------------------------------------------------------------------------------------
# Set up file lists for processing
#-------------------------------------------------------------------------------------------------------

# HRRR files

hrrr_dir   = '/Users/Louis.Wicker/CAM_Case_Studies/20210526/HRRR'
hrrr_files = sorted(glob.glob(hrrr_dir+'/hrrr.t12z.wrfnat*'))

# RRFS dir

rrfs_dir   = '/Users/Louis.Wicker/CAM_Case_Studies/20210526/RRFS/ctrl'
rrfs_files = sorted(glob.glob(rrfs_dir+'/PRSLEV.Grb*'))

# %%
#-------------------------------------------------------------------------------------------------------
# Specify regional domain
# This is tricky, you need to know where to put the domain before you can actually see it easily

# One way is to process a single file perhaps when convection is active, and then choose the domain.  
# Ideally, the domains should be nx > 500, ny > 500, e.g., about 12-15 degrees in both dlat and dlon
#-------------------------------------------------------------------------------------------------------
#
# May 26 Case (NW KS) domain

sw_corner = (30.0, -105.0)
ne_corner = (43.0, -91.0)

#-------------------------------------------------------------------------------------------------------
# XXX Case

# %%
#ret = quickplotgrib('/Users/Louis.Wicker/CAM_Case_Studies/20210526/HRRR/hrrr.t12z.wrfnatf13.grib2', klevel=25)
ret = quickplotgrib('/Users/Louis.Wicker/CAM_Case_Studies/20210526/RRFS/ctrl/PRSLEV.GrbF12', klevel=20, filetype='rrfs')
# Out:
# Grib File Lat Min: 21.9  Lat Max:  52.0
#
# Grib File Lon Min: -132.8  Lon Max:  -62.2
#
# Grib File W Min: -28.3  W Max:  -5.7
#
#
# Plot Lat Min: 25.0  Lat Max:  50.0
#
# Plot Lon Min: -130.0  Lon Max:  -65.0

# %%
#-------------------------------------------------------------------------------------------------------
#
# Process the HRRR files - the call to read the grib files returns the xarray data set and the NCDF filename
#
#-------------------------------------------------------------------------------------------------------

for file in hrrr_files:
    hrrr_ds, filename = hrrr_grib_read_variable(file, sw_corner = sw_corner, ne_corner = ne_corner, var_list=[''], writeout=True, prefix=None)
# Out:
# -105.11639
# /Users/Louis.Wicker/miniconda3/envs/ray/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1797: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   result = matplotlib.axes.Axes.pcolormesh(self, *args, **kwargs)
# /Users/Louis.Wicker/miniconda3/envs/ray/lib/python3.9/site-packages/cartopy/crs.py:825: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /Users/Louis.Wicker/miniconda3/envs/ray/lib/python3.9/site-packages/cartopy/crs.py:877: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for line in multi_line_string:
# /Users/Louis.Wicker/miniconda3/envs/ray/lib/python3.9/site-packages/cartopy/crs.py:944: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(p_mline) > 0:

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(30,20))
xlim = None
ylim = None
klevel=20

utc = 00
colormap = 'viridis'
plevel = plevels[klevel]

if klevel < 10:
    vmin = -5.
    vmax = 10.
    clevels = np.linspace(vmin, vmax, 16)
else:
    vmin = -10.
    vmax = 20.
    clevels = np.linspace(vmin, vmax, 16)
    
b.W.isel(nz=klevel).plot.contourf(ax=axes[0], levels=clevels, xlim=xlim, ylim=ylim, cmap=colormap, cbar_kwargs={'label': 'W (m/s)'})
axes[0].set_title(title_string(utc, plevel, 'RRFS-ctrl W', b.W.isel(nz=klevel).max(), b.W.isel(nz=klevel).min()), fontsize=16)

a.W.isel(nz=klevel).plot.contourf(ax=axes[1], levels=clevels, xlim=xlim, ylim=ylim, cmap=colormap, cbar_kwargs={'label': 'W (m/s)'})
axes[1].set_title(title_string(utc, plevel, 'RRFS-nord3 W', a.W.isel(nz=klevel).max(), a.W.isel(nz=klevel).min()), fontsize=16)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/69/4qhl_6_11bd5cnfchf53rn880001k2/T/ipykernel_10649/1260364889.py in <module>
#      17     clevels = np.linspace(vmin, vmax, 16)
#      18
# ---> 19 b.W.isel(nz=klevel).plot.contourf(ax=axes[0], levels=clevels, xlim=xlim, ylim=ylim, cmap=colormap, cbar_kwargs={'label': 'W (m/s)'})
#      20 axes[0].set_title(title_string(utc, plevel, 'RRFS-ctrl W', b.W.isel(nz=klevel).max(), b.W.isel(nz=klevel).min()), fontsize=16)
#      21
#
# NameError: name 'b' is not defined

# %%
file = '/Users/Louis.Wicker/CAM_Case_Studies/20210526/HRRR/hrrr.20210526_conus_hrrr.t00z.wrfnatf24.grib2'
b, filename = fv3_grib_read_variable(file, var_list=['W','CREF'], writeout=True, prefix=None)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
#
# FV3_Extract: Extracting variables from grib file: /Users/Louis.Wicker/CAM_Case_Studies/20210526/HRRR/hrrr.20210526_conus_hrrr.t00z.wrfnatf24.grib2
#
# Reading my variable:  W from GRIB variable:  Geometric vertical velocity
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/69/4qhl_6_11bd5cnfchf53rn880001k2/T/ipykernel_22997/527324871.py in <module>
#       1 file = '/Users/Louis.Wicker/CAM_Case_Studies/20210526/HRRR/hrrr.20210526_conus_hrrr.t00z.wrfnatf24.grib2'
# ----> 2 b, filename = fv3_grib_read_variable(file, var_list=['W','CREF'], writeout=True, prefix=None)
#
# ~/Jupyter_Notebooks/FV3_ARW_tools/file_tools.py in fv3_grib_read_variable(file, sw_corner, ne_corner, var_list, writeout, prefix)
#     120                                             "lons": (["ny","nx"], lons) } )
#     121             else:
# --> 122                 cube = grbVar_to_cube(grb_var, type='isobaricInhPa')
#     123                 pres = cube['levels']
#     124
#
# ~/Jupyter_Notebooks/FV3_ARW_tools/file_tools.py in grbVar_to_cube(grb_obj, type)
#      63     n_levels   = len(levels)
#      64     indexes    = np.argsort(levels)[::-1] # highest pressure first
# ---> 65     cube       = np.zeros([n_levels, grb_obj[0].values.shape[0], grb_obj[1].values.shape[1]])
#      66
#      67     for k in range(n_levels):
#
# IndexError: list index out of range

# %%
fv3_dir   = '/Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/'
fv3_files = sorted(glob.glob(fv3_dir+'/rrfs.*.nc4'))
ds_FV3 = []

for file in fv3_files:
    
    ds_FV3.append(fv3_extract_variables_over_region(file, sw_corner = sw_corner, ne_corner = ne_corner, writeout=True, prefix=None))
    print(f'Successfully created dataframe for file:  {file}\n')
# Out:
# ------------------------------------------------------------------------------------------------------------------------
#
# FV3_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf018.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/region.t00z.mem01.naf018.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf018.nc4
#
# ------------------------------------------------------------------------------------------------------------------------
#
# FV3_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf019.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/region.t00z.mem01.naf019.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf019.nc4
#
# ------------------------------------------------------------------------------------------------------------------------
#
# FV3_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf020.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/region.t00z.mem01.naf020.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf020.nc4
#
# ------------------------------------------------------------------------------------------------------------------------
#
# FV3_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf021.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/region.t00z.mem01.naf021.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf021.nc4
#
# ------------------------------------------------------------------------------------------------------------------------
#
# FV3_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf022.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/region.t00z.mem01.naf022.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf022.nc4
#
# ------------------------------------------------------------------------------------------------------------------------
#
# FV3_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf023.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/region.t00z.mem01.naf023.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf023.nc4
#
# ------------------------------------------------------------------------------------------------------------------------
#
# FV3_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf024.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/region.t00z.mem01.naf024.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/RRFS/rrfs.t00z.mem01.naf024.nc4

# %%
arw_dir   = '/Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR'
arw_files = sorted(glob.glob(arw_dir+'/hrrr.*.nc4'))

ds_WRF = []

for file in arw_files:

    tmp, outfilename = wrf_extract_variables_over_region(file, sw_corner = sw_corner, ne_corner = ne_corner, writeout=True, prefix=None)
    print(f'Successfully created dataframe for file:  {file}','\n')

    ds_WRF.append(tmp)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
#
# WRF_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf18.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully interpolated fields from file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf18.nc4
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/region.20210504_conus_hrrr.t00z.wrfnatf18.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf18.nc4
#
# ------------------------------------------------------------------------------------------------------------------------
#
# WRF_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf19.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully interpolated fields from file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf19.nc4
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/region.20210504_conus_hrrr.t00z.wrfnatf19.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf19.nc4
#
# ------------------------------------------------------------------------------------------------------------------------
#
# WRF_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf20.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully interpolated fields from file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf20.nc4
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/region.20210504_conus_hrrr.t00z.wrfnatf20.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf20.nc4
#
# ------------------------------------------------------------------------------------------------------------------------
#
# WRF_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf21.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully interpolated fields from file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf21.nc4
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/region.20210504_conus_hrrr.t00z.wrfnatf21.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf21.nc4
#
# ------------------------------------------------------------------------------------------------------------------------
#
# WRF_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf22.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully interpolated fields from file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf22.nc4
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/region.20210504_conus_hrrr.t00z.wrfnatf22.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf22.nc4
#
# ------------------------------------------------------------------------------------------------------------------------
#
# WRF_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf23.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully interpolated fields from file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf23.nc4
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/region.20210504_conus_hrrr.t00z.wrfnatf23.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf23.nc4
#
# ------------------------------------------------------------------------------------------------------------------------
#
# WRF_Extract: Extracting variables over region from input file: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf24.nc4
#
# Creating a sub-region of DataArray: 27.78, -97.43, 38.36, -81.65
#
# Successfully interpolated fields from file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf24.nc4
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/region.20210504_conus_hrrr.t00z.wrfnatf24.nc4
#
# Successfully created dataframe for file:  /Users/Louis.Wicker/CAM_Case_Studies/2021050400/HRRR/hrrr.20210504_conus_hrrr.t00z.wrfnatf24.nc4

# %%
figsize = (20,10)
fig, (ax1,ax2) = plt.subplots(1,2, figsize = figsize)

wrf_mean = np.zeros((7,nz_new))
fv3_mean = np.zeros((7,nz_new))

for n, item in enumerate(ds_WRF):
    dsW_WRF = item.where( item.W_interp > _w_threshold )
    dsWmean_WRF = dsW_WRF.W_interp.mean(dim=("ny","nx"), skipna=True, keep_attrs=False)
    ax1.plot(dsWmean_WRF.values, plevels/100., color='black')
    wrf_mean[n,:] = dsWmean_WRF.values

for n, item in enumerate(ds_FV3):    
    dsW_FV3 = item.where( item.W > _w_threshold )
    dsWmean_FV3 = dsW_FV3.W.mean(dim=("ny","nx"), skipna=True, keep_attrs=False)
    ax1.plot(dsWmean_FV3.values, plevels/100., color='red')
    fv3_mean[n,:] = dsWmean_FV3.values
    
ax1.invert_yaxis()
ax2.invert_yaxis()

ax2.plot(wrf_mean.mean(axis=0), plevels/100., color='black')
ax2.plot(fv3_mean.mean(axis=0), plevels/100., color='red')
ax1.legend()
ax2.legend()
ax1.set_title("Hourly WRF and FV3 Regional Udraft profiles from 18-00Z")
ax2.set_title("Average WRF and FV3 regional Udraft profiles")
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-bf6e7dbb1e8b> in <module>
#      24 ax1.legend()
#      25 ax2.legend()
# ---> 26 ax1.title("Hourly WRF and FV3 Regional Udraft profiles from 18-00Z")
#      27 ax2.title("Average WRF and FV3 regional Udraft profiles")
#      28
#
# TypeError: 'Text' object is not callable

# %%
file = '/Users/Louis.Wicker/CAM_Case_Studies/20210526/RRFS/nord3/PRSLEV.GrbF06'
fv3_grib_read_variable(file, sw_corner = sw_corner, ne_corner = ne_corner, var_list=['W'], writeout=True, prefix=None)
# Out:
# ------------------------------------------------------------------------------------------------------------------------
#
# FV3_Extract: Extracting variables from grib file: /Users/Louis.Wicker/CAM_Case_Studies/20210526/RRFS/nord3/PRSLEV.GrbF06
#
# Reading my variable:  W from GRIB variable:  Geometric vertical velocity
# [[21.885885   21.89274894 21.89960579 ... 21.90003623 21.89317983
#   21.88631633]
#  [21.91088713 21.91775389 21.92461354 ... 21.92504416 21.91818495
#   21.91131864]
#  [21.93589164 21.94276121 21.94962368 ... 21.95005448 21.94319245
#   21.93632332]
#  ...
#  [47.50741887 47.51736668 47.52730438 ... 47.52792824 47.51799117
#   47.50804399]
#  [47.53211797 47.54206901 47.55200993 ... 47.55263398 47.5426937
#   47.5327433 ]
#  [47.55681366 47.56676792 47.57671206 ... 47.57733632 47.56739281
#   47.55743919]]
# Creating a sub-region of conus grid: 27.78, -97.43, 38.36, -81.65
#
# Successfully wrote new data to file:: /Users/Louis.Wicker/CAM_Case_Studies/20210526/RRFS/nord3/conus_F06.nc
# (<xarray.Dataset>
#  Dimensions:  (nz: 45, ny: 0, nx: 0)
#  Coordinates:
#      lats     (ny, nx) float64
#      lons     (ny, nx) float64
#      pres     (nz) int64 1000 975 950 925 900 875 850 825 ... 50 30 20 10 7 5 2
#  Dimensions without coordinates: nz, ny, nx
#  Data variables:
#      W        (nz, ny, nx) float64
#      plevels  (nz, ny, nx) float64 ,
#  '/Users/Louis.Wicker/CAM_Case_Studies/20210526/RRFS/nord3/conus_F06.nc')

# %%
fig = plt.subplots(figsize = (20,20))
plt.imshow(d2d.orog[::-1,:])

# %%
ds.data_vars
# Out:
# Data variables:
#     gh       (isobaricInhPa, y, x) float32 167.5 167.5 ... 4.302e+04 4.302e+04
#     t        (isobaricInhPa, y, x) float32 289.4 289.4 289.4 ... 257.7 257.6
#     r        (isobaricInhPa, y, x) float32 80.0 80.0 80.0 ... 0.0001 0.0001
#     dpt      (isobaricInhPa, y, x) float32 285.9 285.9 285.9 ... 192.1 192.1
#     q        (isobaricInhPa, y, x) float32 0.00918 0.00919 ... 5.68e-07 5.67e-07
#     w        (isobaricInhPa, y, x) float32 0.082 0.091 ... 0.00195 0.001946
#     wz       (isobaricInhPa, y, x) float32 -0.0132 -0.0132 ... -0.04946 -0.04946
#     u        (isobaricInhPa, y, x) float32 -1.63 -1.6 -1.57 ... -4.43 -4.42
#     v        (isobaricInhPa, y, x) float32 -5.29 -5.29 -5.29 ... 2.67 2.67 2.67
#     tke      (isobaricInhPa, y, x) float32 nan nan nan nan ... nan nan nan nan
#     clwmr    (isobaricInhPa, y, x) float32 0.0 0.0 0.0 0.0 ... 1e-12 1e-12 1e-12
#     icmr     (isobaricInhPa, y, x) float32 1e-12 1e-12 1e-12 ... 1e-12 1e-12
#     rwmr     (isobaricInhPa, y, x) float32 0.0 0.0 0.0 0.0 ... 1e-12 1e-12 1e-12
#     snmr     (isobaricInhPa, y, x) float32 1e-12 1e-12 1e-12 ... 1e-12 1e-12
#     grle     (isobaricInhPa, y, x) float32 0.0 0.0 0.0 0.0 ... 1e-12 1e-12 1e-12
#     rime     (isobaricInhPa, y, x) float32 nan nan nan nan ... nan nan nan nan

# %%
ds.wz.data.max()
# Out:
# 18.00525

# %%
d3 = xr.load_dataset(file, engine="cfgrib", filter_by_keys={'typeOfLevel': 'heightAboveSea'})
# Out:
# skipping variable: paramId==133 shortName='q'
# Traceback (most recent call last):
#   File "/Users/Louis.Wicker/miniconda3/envs/main/lib/python3.9/site-packages/cfgrib/dataset.py", line 660, in build_dataset_components
#     dict_merge(variables, coord_vars)
#   File "/Users/Louis.Wicker/miniconda3/envs/main/lib/python3.9/site-packages/cfgrib/dataset.py", line 591, in dict_merge
#     raise DatasetBuildError(
# cfgrib.dataset.DatasetBuildError: key present and new value is different: key='heightAboveSea' value=Variable(dimensions=('heightAboveSea',), data=array([ 305.,  457.,  610.,  914., 1524., 1829., 2134., 2743., 3658.,
#        4572.])) new_value=Variable(dimensions=(), data=305.0)

# %%
d3.data_vars
# Out:
# Data variables:
#     t        (heightAboveSea, y, x) float32 288.1 288.1 288.1 ... 268.3 268.3
#     u        (heightAboveSea, y, x) float32 -1.64 -1.61 -1.59 ... 22.19 22.17
#     v        (heightAboveSea, y, x) float32 -5.26 -5.25 -5.25 ... -3.17 -3.22

# %%
txt = ('stepType': 'instant', 'typeOfLevel': 'surface')
# Out:
#   File "/var/folders/69/4qhl_6_11bd5cnfchf53rn880001k2/T/ipykernel_98164/2502260557.py", line 1
#     txt = ('stepType': 'instant', 'typeOfLevel': 'surface')
#                      ^
# SyntaxError: invalid syntax

# %%
# Out:
# [autoreload of file_tools failed: Traceback (most recent call last):
#   File "/Users/Louis.Wicker/miniconda3/envs/main/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/Louis.Wicker/miniconda3/envs/main/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/Users/Louis.Wicker/miniconda3/envs/main/lib/python3.9/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/Louis.Wicker/miniconda3/envs/main/lib/python3.9/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 613, in _exec
#   File "<frozen importlib._bootstrap_external>", line 846, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 983, in get_code
#   File "<frozen importlib._bootstrap_external>", line 913, in source_to_code
#   File "<frozen importlib._bootstrap>", line 228, in _call_with_frames_removed
#   File "/Users/Louis.Wicker/Jupyter_Notebooks/FV3_ARW_tools/file_tools.py", line 70
#     'sfc_height':   ['HGT_P0_L1_GRLL0',    'SFC_HGT', 2, ('stepType': 'instant', 'typeOfLevel': 'surface'}],
#                                                                     ^
# SyntaxError: invalid syntax
# ]

# %%
file = '/Users/Louis.Wicker/CAM_Case_Studies/20210526/RRFS/nord3/PRSLEV.GrbF06'

g = pygrib.open(file)

for gr in g:
    print(gr)
# Out:
# 1:Pressure reduced to MSL:Pa (instant):lambert:meanSea:level 0:fcst time 6 hrs:from 202105261200
# 2:Pressure:Pa (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 3:Cloud mixing ratio:kg kg**-1 (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 4:Ice water mixing ratio:kg kg**-1 (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 5:Rain mixing ratio:kg kg**-1 (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 6:Snow mixing ratio:kg kg**-1 (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 7:Graupel (snow pellets):kg kg**-1 (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 8:Total Cloud Cover:% (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 9:Derived radar reflectivity:dB (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 10:Condensate:kg kg**-1 (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 11:Rime factor:Numeric (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 12:Geopotential Height:gpm (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 13:Temperature:K (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 14:Potential temperature:K (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 15:Relative humidity:% (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 16:Dew point temperature:K (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 17:Specific humidity:kg kg**-1 (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 18:U component of wind:m s**-1 (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 19:V component of wind:m s**-1 (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 20:Vertical velocity:Pa s**-1 (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 21:Geometric vertical velocity:m s**-1 (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 22:Turbulent kinetic energy:J kg**-1 (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 23:Pressure:Pa (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 24:Cloud mixing ratio:kg kg**-1 (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 25:Ice water mixing ratio:kg kg**-1 (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 26:Rain mixing ratio:kg kg**-1 (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 27:Snow mixing ratio:kg kg**-1 (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 28:Graupel (snow pellets):kg kg**-1 (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 29:Total Cloud Cover:% (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 30:Derived radar reflectivity:dB (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 31:Condensate:kg kg**-1 (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 32:Rime factor:Numeric (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 33:Geopotential Height:gpm (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 34:Temperature:K (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 35:Potential temperature:K (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 36:Dew point temperature:K (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 37:U component of wind:m s**-1 (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 38:V component of wind:m s**-1 (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 39:Turbulent kinetic energy:J kg**-1 (instant):lambert:hybrid:level 2:fcst time 6 hrs:from 202105261200
# 40:Maximum/Composite radar reflectivity:dB (instant):lambert:atmosphereSingleLayer:level 0 considered as a single layer:fcst time 6 hrs:from 202105261200
# 41:Vertically-integrated liquid:kg m**-1 (instant):lambert:atmosphereSingleLayer:level 0 considered as a single layer:fcst time 6 hrs:from 202105261200
# 42:Derived radar reflectivity backscatter from rain:mm**6 m**-3 (instant):lambert:atmosphereSingleLayer:level 0 considered as a single layer:fcst time 6 hrs:from 202105261200
# 43:Derived radar reflectivity backscatter from ice:mm**6 m**-3 (instant):lambert:atmosphereSingleLayer:level 0 considered as a single layer:fcst time 6 hrs:from 202105261200
# 44:Visibility:m (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 45:Derived radar reflectivity:dB (instant):lambert:isothermal:level 263 K:fcst time 6 hrs:from 202105261200
# 46:Blackadar mixing length scale:m (instant):lambert:hybrid:level 1:fcst time 6 hrs:from 202105261200
# 47:Geopotential Height:gpm (instant):lambert:planetaryBoundaryLayer:level 0:fcst time 6 hrs:from 202105261200
# 48:U component of wind:m s**-1 (instant):lambert:planetaryBoundaryLayer:level 0:fcst time 6 hrs:from 202105261200
# 49:V component of wind:m s**-1 (instant):lambert:planetaryBoundaryLayer:level 0:fcst time 6 hrs:from 202105261200
# 50:Ventilation Rate:m**2 s**-1 (instant):lambert:planetaryBoundaryLayer:level 0:fcst time 6 hrs:from 202105261200
# 51:Wind speed (gust):m s**-1 (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 52:Planetary boundary layer regime:code table (4.209) (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 53:197:197 (instant):lambert:atmosphereSingleLayer:level 0 considered as a single layer:fcst time 6 hrs:from 202105261200
# 54:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 55:Temperature:K (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 56:Relative humidity:% (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 57:Dew point temperature:K (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 58:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 59:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 60:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 61:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 62:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 63:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 64:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 65:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 66:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 67:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 68:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 69:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 200 Pa:fcst time 6 hrs:from 202105261200
# 70:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 71:Temperature:K (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 72:Relative humidity:% (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 73:Dew point temperature:K (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 74:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 75:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 76:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 77:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 78:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 79:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 80:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 81:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 82:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 83:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 84:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 85:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 500 Pa:fcst time 6 hrs:from 202105261200
# 86:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 87:Temperature:K (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 88:Relative humidity:% (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 89:Dew point temperature:K (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 90:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 91:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 92:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 93:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 94:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 95:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 96:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 97:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 98:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 99:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 100:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 101:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 700 Pa:fcst time 6 hrs:from 202105261200
# 102:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 103:Temperature:K (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 104:Relative humidity:% (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 105:Dew point temperature:K (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 106:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 107:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 108:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 109:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 110:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 111:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 112:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 113:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 114:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 115:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 116:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 117:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 1000 Pa:fcst time 6 hrs:from 202105261200
# 118:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 119:Temperature:K (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 120:Relative humidity:% (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 121:Dew point temperature:K (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 122:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 123:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 124:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 125:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 126:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 127:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 128:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 129:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 130:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 131:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 132:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 133:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 2000 Pa:fcst time 6 hrs:from 202105261200
# 134:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 135:Temperature:K (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 136:Relative humidity:% (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 137:Dew point temperature:K (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 138:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 139:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 140:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 141:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 142:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 143:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 144:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 145:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 146:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 147:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 148:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 149:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 3000 Pa:fcst time 6 hrs:from 202105261200
# 150:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 151:Temperature:K (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 152:Relative humidity:% (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 153:Dew point temperature:K (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 154:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 155:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 156:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 157:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 158:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 159:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 160:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 161:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 162:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 163:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 164:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 165:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 5000 Pa:fcst time 6 hrs:from 202105261200
# 166:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 167:Temperature:K (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 168:Relative humidity:% (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 169:Dew point temperature:K (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 170:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 171:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 172:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 173:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 174:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 175:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 176:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 177:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 178:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 179:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 180:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 181:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 7000 Pa:fcst time 6 hrs:from 202105261200
# 182:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 183:Temperature:K (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 184:Relative humidity:% (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 185:Dew point temperature:K (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 186:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 187:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 188:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 189:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 190:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 191:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 192:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 193:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 194:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 195:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 196:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 197:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 10000 Pa:fcst time 6 hrs:from 202105261200
# 198:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 199:Temperature:K (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 200:Relative humidity:% (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 201:Dew point temperature:K (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 202:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 203:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 204:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 205:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 206:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 207:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 208:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 209:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 210:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 211:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 212:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 213:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 12500 Pa:fcst time 6 hrs:from 202105261200
# 214:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 215:Temperature:K (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 216:Relative humidity:% (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 217:Dew point temperature:K (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 218:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 219:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 220:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 221:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 222:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 223:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 224:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 225:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 226:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 227:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 228:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 229:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 15000 Pa:fcst time 6 hrs:from 202105261200
# 230:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 231:Temperature:K (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 232:Relative humidity:% (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 233:Dew point temperature:K (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 234:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 235:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 236:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 237:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 238:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 239:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 240:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 241:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 242:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 243:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 244:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 245:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 17500 Pa:fcst time 6 hrs:from 202105261200
# 246:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 247:Temperature:K (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 248:Relative humidity:% (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 249:Dew point temperature:K (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 250:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 251:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 252:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 253:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 254:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 255:Absolute vorticity:s**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 256:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 257:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 258:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 259:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 260:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 261:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 262:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 20000 Pa:fcst time 6 hrs:from 202105261200
# 263:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 264:Temperature:K (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 265:Relative humidity:% (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 266:Dew point temperature:K (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 267:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 268:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 269:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 270:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 271:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 272:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 273:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 274:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 275:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 276:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 277:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 278:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 22500 Pa:fcst time 6 hrs:from 202105261200
# 279:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 280:Temperature:K (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 281:Relative humidity:% (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 282:Dew point temperature:K (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 283:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 284:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 285:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 286:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 287:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 288:Absolute vorticity:s**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 289:Stream function:m**2 s**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 290:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 291:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 292:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 293:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 294:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 295:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 296:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 25000 Pa:fcst time 6 hrs:from 202105261200
# 297:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 298:Temperature:K (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 299:Relative humidity:% (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 300:Dew point temperature:K (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 301:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 302:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 303:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 304:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 305:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 306:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 307:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 308:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 309:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 310:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 311:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 312:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 27500 Pa:fcst time 6 hrs:from 202105261200
# 313:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 314:Temperature:K (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 315:Relative humidity:% (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 316:Dew point temperature:K (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 317:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 318:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 319:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 320:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 321:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 322:Absolute vorticity:s**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 323:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 324:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 325:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 326:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 327:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 328:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 329:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 30000 Pa:fcst time 6 hrs:from 202105261200
# 330:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 331:Temperature:K (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 332:Relative humidity:% (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 333:Dew point temperature:K (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 334:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 335:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 336:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 337:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 338:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 339:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 340:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 341:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 342:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 343:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 344:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 345:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 32500 Pa:fcst time 6 hrs:from 202105261200
# 346:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 347:Temperature:K (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 348:Relative humidity:% (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 349:Dew point temperature:K (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 350:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 351:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 352:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 353:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 354:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 355:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 356:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 357:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 358:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 359:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 360:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 361:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 35000 Pa:fcst time 6 hrs:from 202105261200
# 362:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 363:Temperature:K (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 364:Relative humidity:% (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 365:Dew point temperature:K (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 366:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 367:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 368:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 369:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 370:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 371:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 372:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 373:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 374:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 375:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 376:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 377:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 37500 Pa:fcst time 6 hrs:from 202105261200
# 378:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 379:Temperature:K (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 380:Relative humidity:% (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 381:Dew point temperature:K (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 382:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 383:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 384:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 385:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 386:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 387:Absolute vorticity:s**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 388:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 389:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 390:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 391:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 392:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 393:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 394:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 40000 Pa:fcst time 6 hrs:from 202105261200
# 395:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 396:Temperature:K (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 397:Relative humidity:% (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 398:Dew point temperature:K (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 399:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 400:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 401:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 402:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 403:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 404:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 405:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 406:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 407:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 408:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 409:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 410:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 42500 Pa:fcst time 6 hrs:from 202105261200
# 411:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 412:Temperature:K (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 413:Relative humidity:% (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 414:Dew point temperature:K (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 415:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 416:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 417:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 418:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 419:V component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 420:Turbulent kinetic energy:J kg**-1 (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 421:Cloud mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 422:Ice water mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 423:Rain mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 424:Snow mixing ratio:kg kg**-1 (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 425:Graupel (snow pellets):kg kg**-1 (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 426:Rime factor:Numeric (instant):lambert:isobaricInhPa:level 45000 Pa:fcst time 6 hrs:from 202105261200
# 427:Geopotential Height:gpm (instant):lambert:isobaricInhPa:level 47500 Pa:fcst time 6 hrs:from 202105261200
# 428:Temperature:K (instant):lambert:isobaricInhPa:level 47500 Pa:fcst time 6 hrs:from 202105261200
# 429:Relative humidity:% (instant):lambert:isobaricInhPa:level 47500 Pa:fcst time 6 hrs:from 202105261200
# 430:Dew point temperature:K (instant):lambert:isobaricInhPa:level 47500 Pa:fcst time 6 hrs:from 202105261200
# 431:Specific humidity:kg kg**-1 (instant):lambert:isobaricInhPa:level 47500 Pa:fcst time 6 hrs:from 202105261200
# 432:Vertical velocity:Pa s**-1 (instant):lambert:isobaricInhPa:level 47500 Pa:fcst time 6 hrs:from 202105261200
# 433:Geometric vertical velocity:m s**-1 (instant):lambert:isobaricInhPa:level 47500 Pa:fcst time 6 hrs:from 202105261200
# 434:U component of wind:m s**-1 (instant):lambert:isobaricInhPa:level 47500 Pa:fcst time 6 hrs:from 202105261200
# ...
# 936:Upward long-wave radiation flux:W m**-2 (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 937:Clear Sky Downward Solar Flux:W m**-2 (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 938:Storm relative helicity:J kg**-1 (instant):lambert:heightAboveGroundLayer:levels 3000-0 m:fcst time 6 hrs:from 202105261200
# 939:Storm relative helicity:J kg**-1 (instant):lambert:heightAboveGroundLayer:levels 1000-0 m:fcst time 6 hrs:from 202105261200
# 940:U-component storm motion:m s**-1 (instant):lambert:heightAboveGroundLayer:levels 6000-0 m:fcst time 6 hrs:from 202105261200
# 941:V-component storm motion:m s**-1 (instant):lambert:heightAboveGroundLayer:levels 6000-0 m:fcst time 6 hrs:from 202105261200
# 942:Updraft Helicity:m**2 s**-2 (instant):lambert:heightAboveGroundLayer:levels 5000-2000 m:fcst time 6 hrs:from 202105261200
# 943:Vertical u-component shear:s**-1 (instant):lambert:heightAboveGroundLayer:levels 0-1000 m:fcst time 6 hrs:from 202105261200
# 944:Vertical v-component shear:s**-1 (instant):lambert:heightAboveGroundLayer:levels 0-1000 m:fcst time 6 hrs:from 202105261200
# 945:Vertical u-component shear:s**-1 (instant):lambert:heightAboveGroundLayer:levels 0-6000 m:fcst time 6 hrs:from 202105261200
# 946:Vertical v-component shear:s**-1 (instant):lambert:heightAboveGroundLayer:levels 0-6000 m:fcst time 6 hrs:from 202105261200
# 947:Tropopause pressure:Pa (instant):lambert:tropopause:level 0:fcst time 6 hrs:from 202105261200
# 948:Geopotential Height:gpm (instant):lambert:tropopause:level 0:fcst time 6 hrs:from 202105261200
# 949:Temperature:K (instant):lambert:tropopause:level 0:fcst time 6 hrs:from 202105261200
# 950:Potential temperature:K (instant):lambert:tropopause:level 0:fcst time 6 hrs:from 202105261200
# 951:U component of wind:m s**-1 (instant):lambert:tropopause:level 0:fcst time 6 hrs:from 202105261200
# 952:V component of wind:m s**-1 (instant):lambert:tropopause:level 0:fcst time 6 hrs:from 202105261200
# 953:Vertical speed shear:s**-1 (instant):lambert:tropopause:level 0:fcst time 6 hrs:from 202105261200
# 954:Pressure:Pa (instant):lambert:maxWind:level 0:fcst time 6 hrs:from 202105261200
# 955:Geopotential Height:gpm (instant):lambert:maxWind:level 0:fcst time 6 hrs:from 202105261200
# 956:U component of wind:m s**-1 (instant):lambert:maxWind:level 0:fcst time 6 hrs:from 202105261200
# 957:V component of wind:m s**-1 (instant):lambert:maxWind:level 0:fcst time 6 hrs:from 202105261200
# 958:Temperature:K (instant):lambert:heightAboveGround:level 30 m:fcst time 6 hrs:from 202105261200
# 959:Specific humidity:kg kg**-1 (instant):lambert:heightAboveGround:level 30 m:fcst time 6 hrs:from 202105261200
# 960:Pressure:Pa (instant):lambert:heightAboveGround:level 30 m:fcst time 6 hrs:from 202105261200
# 961:U component of wind:m s**-1 (instant):lambert:heightAboveGround:level 30 m:fcst time 6 hrs:from 202105261200
# 962:V component of wind:m s**-1 (instant):lambert:heightAboveGround:level 30 m:fcst time 6 hrs:from 202105261200
# 963:Temperature:K (instant):lambert:heightAboveGround:level 50 m:fcst time 6 hrs:from 202105261200
# 964:Specific humidity:kg kg**-1 (instant):lambert:heightAboveGround:level 50 m:fcst time 6 hrs:from 202105261200
# 965:Pressure:Pa (instant):lambert:heightAboveGround:level 50 m:fcst time 6 hrs:from 202105261200
# 966:U component of wind:m s**-1 (instant):lambert:heightAboveGround:level 50 m:fcst time 6 hrs:from 202105261200
# 967:V component of wind:m s**-1 (instant):lambert:heightAboveGround:level 50 m:fcst time 6 hrs:from 202105261200
# 968:Temperature:K (instant):lambert:heightAboveGround:level 80 m:fcst time 6 hrs:from 202105261200
# 969:Specific humidity:kg kg**-1 (instant):lambert:heightAboveGround:level 80 m:fcst time 6 hrs:from 202105261200
# 970:Pressure:Pa (instant):lambert:heightAboveGround:level 80 m:fcst time 6 hrs:from 202105261200
# 971:U component of wind:m s**-1 (instant):lambert:heightAboveGround:level 80 m:fcst time 6 hrs:from 202105261200
# 972:V component of wind:m s**-1 (instant):lambert:heightAboveGround:level 80 m:fcst time 6 hrs:from 202105261200
# 973:Temperature:K (instant):lambert:heightAboveGround:level 100 m:fcst time 6 hrs:from 202105261200
# 974:Specific humidity:kg kg**-1 (instant):lambert:heightAboveGround:level 100 m:fcst time 6 hrs:from 202105261200
# 975:Pressure:Pa (instant):lambert:heightAboveGround:level 100 m:fcst time 6 hrs:from 202105261200
# 976:100 metre U wind component:m s**-1 (instant):lambert:heightAboveGround:level 100 m:fcst time 6 hrs:from 202105261200
# 977:100 metre V wind component:m s**-1 (instant):lambert:heightAboveGround:level 100 m:fcst time 6 hrs:from 202105261200
# 978:Temperature:K (instant):lambert:heightAboveSea:level 305 m:fcst time 6 hrs:from 202105261200
# 979:Specific humidity:kg kg**-1 (instant):lambert:heightAboveSea:level 305 m:fcst time 6 hrs:from 202105261200
# 980:U component of wind:m s**-1 (instant):lambert:heightAboveSea:level 305 m:fcst time 6 hrs:from 202105261200
# 981:V component of wind:m s**-1 (instant):lambert:heightAboveSea:level 305 m:fcst time 6 hrs:from 202105261200
# 982:Temperature:K (instant):lambert:heightAboveSea:level 457 m:fcst time 6 hrs:from 202105261200
# 983:U component of wind:m s**-1 (instant):lambert:heightAboveSea:level 457 m:fcst time 6 hrs:from 202105261200
# 984:V component of wind:m s**-1 (instant):lambert:heightAboveSea:level 457 m:fcst time 6 hrs:from 202105261200
# 985:Temperature:K (instant):lambert:heightAboveSea:level 610 m:fcst time 6 hrs:from 202105261200
# 986:U component of wind:m s**-1 (instant):lambert:heightAboveSea:level 610 m:fcst time 6 hrs:from 202105261200
# 987:V component of wind:m s**-1 (instant):lambert:heightAboveSea:level 610 m:fcst time 6 hrs:from 202105261200
# 988:Temperature:K (instant):lambert:heightAboveSea:level 914 m:fcst time 6 hrs:from 202105261200
# 989:U component of wind:m s**-1 (instant):lambert:heightAboveSea:level 914 m:fcst time 6 hrs:from 202105261200
# 990:V component of wind:m s**-1 (instant):lambert:heightAboveSea:level 914 m:fcst time 6 hrs:from 202105261200
# 991:Temperature:K (instant):lambert:heightAboveSea:level 1524 m:fcst time 6 hrs:from 202105261200
# 992:U component of wind:m s**-1 (instant):lambert:heightAboveSea:level 1524 m:fcst time 6 hrs:from 202105261200
# 993:V component of wind:m s**-1 (instant):lambert:heightAboveSea:level 1524 m:fcst time 6 hrs:from 202105261200
# 994:Temperature:K (instant):lambert:heightAboveSea:level 1829 m:fcst time 6 hrs:from 202105261200
# 995:U component of wind:m s**-1 (instant):lambert:heightAboveSea:level 1829 m:fcst time 6 hrs:from 202105261200
# 996:V component of wind:m s**-1 (instant):lambert:heightAboveSea:level 1829 m:fcst time 6 hrs:from 202105261200
# 997:Temperature:K (instant):lambert:heightAboveSea:level 2134 m:fcst time 6 hrs:from 202105261200
# 998:U component of wind:m s**-1 (instant):lambert:heightAboveSea:level 2134 m:fcst time 6 hrs:from 202105261200
# 999:V component of wind:m s**-1 (instant):lambert:heightAboveSea:level 2134 m:fcst time 6 hrs:from 202105261200
# 1000:Temperature:K (instant):lambert:heightAboveSea:level 2743 m:fcst time 6 hrs:from 202105261200
# 1001:U component of wind:m s**-1 (instant):lambert:heightAboveSea:level 2743 m:fcst time 6 hrs:from 202105261200
# 1002:V component of wind:m s**-1 (instant):lambert:heightAboveSea:level 2743 m:fcst time 6 hrs:from 202105261200
# 1003:Temperature:K (instant):lambert:heightAboveSea:level 3658 m:fcst time 6 hrs:from 202105261200
# 1004:U component of wind:m s**-1 (instant):lambert:heightAboveSea:level 3658 m:fcst time 6 hrs:from 202105261200
# 1005:V component of wind:m s**-1 (instant):lambert:heightAboveSea:level 3658 m:fcst time 6 hrs:from 202105261200
# 1006:Temperature:K (instant):lambert:heightAboveSea:level 4572 m:fcst time 6 hrs:from 202105261200
# 1007:U component of wind:m s**-1 (instant):lambert:heightAboveSea:level 4572 m:fcst time 6 hrs:from 202105261200
# 1008:V component of wind:m s**-1 (instant):lambert:heightAboveSea:level 4572 m:fcst time 6 hrs:from 202105261200
# 1009:Geopotential Height:gpm (instant):lambert:isothermZero:level 0:fcst time 6 hrs:from 202105261200
# 1010:Relative humidity:% (instant):lambert:isothermZero:level 0:fcst time 6 hrs:from 202105261200
# 1011:Geopotential Height:gpm (instant):lambert:highestTroposphericFreezing:level 0:fcst time 6 hrs:from 202105261200
# 1012:Pressure:Pa (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 6 hrs:from 202105261200
# 1013:Temperature:K (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 6 hrs:from 202105261200
# 1014:Potential temperature:K (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 6 hrs:from 202105261200
# 1015:Relative humidity:% (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 6 hrs:from 202105261200
# 1016:Dew point temperature:K (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 6 hrs:from 202105261200
# 1017:Specific humidity:kg kg**-1 (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 6 hrs:from 202105261200
# 1018:Horizontal moisture convergence:kg kg**-1 s**-1 (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 6 hrs:from 202105261200
# 1019:U component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 6 hrs:from 202105261200
# 1020:V component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 6 hrs:from 202105261200
# 1021:Vertical velocity:Pa s**-1 (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 6 hrs:from 202105261200
# 1022:Precipitable water:kg m**-2 (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 6 hrs:from 202105261200
# 1023:Parcel lifted index (to 500 hPa):K (instant):lambert:pressureFromGroundLayer:levels 3000-0 Pa:fcst time 6 hrs:from 202105261200
# 1024:Pressure:Pa (instant):lambert:pressureFromGroundLayer:levels 6000-3000 Pa:fcst time 6 hrs:from 202105261200
# 1025:Temperature:K (instant):lambert:pressureFromGroundLayer:levels 6000-3000 Pa:fcst time 6 hrs:from 202105261200
# 1026:Relative humidity:% (instant):lambert:pressureFromGroundLayer:levels 6000-3000 Pa:fcst time 6 hrs:from 202105261200
# 1027:Specific humidity:kg kg**-1 (instant):lambert:pressureFromGroundLayer:levels 6000-3000 Pa:fcst time 6 hrs:from 202105261200
# 1028:U component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 6000-3000 Pa:fcst time 6 hrs:from 202105261200
# 1029:V component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 6000-3000 Pa:fcst time 6 hrs:from 202105261200
# 1030:Pressure:Pa (instant):lambert:pressureFromGroundLayer:levels 9000-6000 Pa:fcst time 6 hrs:from 202105261200
# 1031:Temperature:K (instant):lambert:pressureFromGroundLayer:levels 9000-6000 Pa:fcst time 6 hrs:from 202105261200
# 1032:Relative humidity:% (instant):lambert:pressureFromGroundLayer:levels 9000-6000 Pa:fcst time 6 hrs:from 202105261200
# 1033:Specific humidity:kg kg**-1 (instant):lambert:pressureFromGroundLayer:levels 9000-6000 Pa:fcst time 6 hrs:from 202105261200
# 1034:U component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 9000-6000 Pa:fcst time 6 hrs:from 202105261200
# 1035:V component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 9000-6000 Pa:fcst time 6 hrs:from 202105261200
# 1036:Vertical velocity:Pa s**-1 (instant):lambert:pressureFromGroundLayer:levels 9000-6000 Pa:fcst time 6 hrs:from 202105261200
# 1037:Pressure:Pa (instant):lambert:pressureFromGroundLayer:levels 12000-9000 Pa:fcst time 6 hrs:from 202105261200
# 1038:Temperature:K (instant):lambert:pressureFromGroundLayer:levels 12000-9000 Pa:fcst time 6 hrs:from 202105261200
# 1039:Relative humidity:% (instant):lambert:pressureFromGroundLayer:levels 12000-9000 Pa:fcst time 6 hrs:from 202105261200
# 1040:Specific humidity:kg kg**-1 (instant):lambert:pressureFromGroundLayer:levels 12000-9000 Pa:fcst time 6 hrs:from 202105261200
# 1041:U component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 12000-9000 Pa:fcst time 6 hrs:from 202105261200
# 1042:V component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 12000-9000 Pa:fcst time 6 hrs:from 202105261200
# 1043:Pressure:Pa (instant):lambert:pressureFromGroundLayer:levels 15000-12000 Pa:fcst time 6 hrs:from 202105261200
# 1044:Temperature:K (instant):lambert:pressureFromGroundLayer:levels 15000-12000 Pa:fcst time 6 hrs:from 202105261200
# 1045:Relative humidity:% (instant):lambert:pressureFromGroundLayer:levels 15000-12000 Pa:fcst time 6 hrs:from 202105261200
# 1046:Specific humidity:kg kg**-1 (instant):lambert:pressureFromGroundLayer:levels 15000-12000 Pa:fcst time 6 hrs:from 202105261200
# 1047:U component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 15000-12000 Pa:fcst time 6 hrs:from 202105261200
# 1048:V component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 15000-12000 Pa:fcst time 6 hrs:from 202105261200
# 1049:Pressure:Pa (instant):lambert:pressureFromGroundLayer:levels 18000-15000 Pa:fcst time 6 hrs:from 202105261200
# 1050:Temperature:K (instant):lambert:pressureFromGroundLayer:levels 18000-15000 Pa:fcst time 6 hrs:from 202105261200
# 1051:Relative humidity:% (instant):lambert:pressureFromGroundLayer:levels 18000-15000 Pa:fcst time 6 hrs:from 202105261200
# 1052:Specific humidity:kg kg**-1 (instant):lambert:pressureFromGroundLayer:levels 18000-15000 Pa:fcst time 6 hrs:from 202105261200
# 1053:U component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 18000-15000 Pa:fcst time 6 hrs:from 202105261200
# 1054:V component of wind:m s**-1 (instant):lambert:pressureFromGroundLayer:levels 18000-15000 Pa:fcst time 6 hrs:from 202105261200
# 1055:Vertical velocity:Pa s**-1 (instant):lambert:pressureFromGroundLayer:levels 18000-15000 Pa:fcst time 6 hrs:from 202105261200
# 1056:Best (4-layer) lifted index:K (instant):lambert:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 6 hrs:from 202105261200
# 1057:Convective available potential energy:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 6 hrs:from 202105261200
# 1058:Convective inhibition:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 18000-0 Pa:fcst time 6 hrs:from 202105261200
# 1059:Planetary boundary layer height:m (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 1060:Geopotential Height:gpm (instant):lambert:adiabaticCondensation:level 0:fcst time 6 hrs:from 202105261200
# 1061:Pressure:Pa (instant):lambert:adiabaticCondensation:level 0:fcst time 6 hrs:from 202105261200
# 1062:Convective available potential energy:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 9000-0 Pa:fcst time 6 hrs:from 202105261200
# 1063:Convective inhibition:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 9000-0 Pa:fcst time 6 hrs:from 202105261200
# 1064:Convective available potential energy:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 25500-0 Pa:fcst time 6 hrs:from 202105261200
# 1065:Convective inhibition:J kg**-1 (instant):lambert:pressureFromGroundLayer:levels 25500-0 Pa:fcst time 6 hrs:from 202105261200
# 1066:Pressure of level from which parcel was lifted:Pa (instant):lambert:pressureFromGroundLayer:levels 25500-0 Pa:fcst time 6 hrs:from 202105261200
# 1067:Lightning:dimensionless (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 1068:Latitude (-90 to +90):deg (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 1069:East Longitude (0 - 360):deg (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 1070:Land-sea mask:(0 - 1) (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 1071:Sea ice area fraction:(0 - 1) (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 1072:Albedo:% (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 1073:Snow free albedo:% (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 1074:Maximum snow albedo:% (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
# 1075:Sea surface temperature:K (instant):lambert:surface:level 0:fcst time 6 hrs:from 202105261200
